# %%
import os, shutil
import ntpath
import sys
import subprocess
from shutil import copyfile
import SimpleITK as sitk
import time


import nibabel as nib
# import matplotlib.pyplot as plt
import os
# from tqdm import tqdm
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
mhdpath = r"F:\PREDICT\SPOTLIGHT_MHD_MAC"
outputpath = r"F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII"

# %%
dirfiles = os.listdir(mhdpath)
i=0;
for x in dirfiles:
    if x.endswith('.mhd'):
        #print(x[:len(x)-4])
        i += 1
        img = sitk.ReadImage(mhdpath + "\\\\" + x)
        outname = outputpath + "\\" + x[:len(x)-4] +".nii"
        print(outname)
        sitk.WriteImage(img, outname)
print(i)
# Out:
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\SPOTLIGHT-018-0001-1-baseline2.nii
# 1

# %%
mhdpath = r"F:\PREDICT\SPOTLIGHT_MHD_MAC"
#file1 = r"F:\PREDICT\SPOTLIGHT_MHD_MAC\single\018-0001-1-baseline-series-Measurement2.mhd"
dirfiles = os.listdir(mhdpath)
i=0;
for x in dirfiles:
    print(x)
    if x.endswith('.mhd'):
        print(x[:len(x)-4])
        i += 1
        img = sitk.ReadImage(mhdpath + "\\" + x)
        outname = outputpath + "\\" + x[:len(x)-4] +".nii"
        print(outname)
        #sitk.WriteImage(img, outname)
print(i)
# Out:
# 002-0001 24HR CT-Parenchymal.mhd
# 002-0001 24HR CT-Parenchymal
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\002-0001 24HR CT-Parenchymal.nii
# 002-0001 24HR CT-Parenchymal.raw
# 002-0001 BL CT-Parenchymal.mhd
# 002-0001 BL CT-Parenchymal
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\002-0001 BL CT-Parenchymal.nii
# 002-0001 BL CT-Parenchymal.raw
# 002-0002 1HR 03MIN CT-Measurement.mhd
# 002-0002 1HR 03MIN CT-Measurement
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\002-0002 1HR 03MIN CT-Measurement.nii
# 002-0002 1HR 03MIN CT-Measurement.raw
# 002-0002 24 HR CT-Measurement.mhd
# 002-0002 24 HR CT-Measurement
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\002-0002 24 HR CT-Measurement.nii
# 002-0002 24 HR CT-Measurement.raw
# 002-0002 BL CT-Measurement.mhd
# 002-0002 BL CT-Measurement
# F:\PREDICT\SPOT-STOP_DCM\SPOTLIGHT_ROI_NII\002-0002 BL CT-Measurement.nii
# 002-0002 BL CT-Measurement.raw
# 002-0003 24 HR CT-Parenchymal.mhd
# 002-0003 24 HR CT-Parenchymal
# ...

# %%
mhdpath = r"F:\PREDICT\PREDICT_MHD_MAC"
outputpath = r"F:\PREDICT\PREDICT_v4_ROI_NII"

# %%
#file1 = r"F:\PREDICT\SPOTLIGHT_MHD_MAC\single\018-0001-1-baseline-series-Measurement2.mhd"
dirfiles = os.listdir(mhdpath)
i=0;
for x in dirfiles:
    print(x)
    if x.endswith('.mhd'):
        print(x[:len(x)-4])
        i += 1
        img = sitk.ReadImage(mhdpath + "\\" + x)
        outname = outputpath + "\\" + x[:len(x)-4] +".nii"
        print(outname)
        sitk.WriteImage(img, outname)
print(i)
# Out:
# PREDICT_01-057-Baseline-Measurement.mhd
# PREDICT_01-057-Baseline-Measurement
# F:\PREDICT\PREDICT_v4_ROI_NII\PREDICT_01-057-Baseline-Measurement.nii
# PREDICT_01-057-Baseline-Measurement.raw
# PREDICT_01-057-Followup-Measurement.mhd
# PREDICT_01-057-Followup-Measurement
# F:\PREDICT\PREDICT_v4_ROI_NII\PREDICT_01-057-Followup-Measurement.nii
# PREDICT_01-057-Followup-Measurement.raw
# PREDICT_01-084-Baseline-ICH-Measurement.mhd
# PREDICT_01-084-Baseline-ICH-Measurement
# F:\PREDICT\PREDICT_v4_ROI_NII\PREDICT_01-084-Baseline-ICH-Measurement.nii
# PREDICT_01-084-Baseline-ICH-Measurement.raw
# PREDICT_01-093-24hrs-ich-Measurement.mhd
# PREDICT_01-093-24hrs-ich-Measurement
# F:\PREDICT\PREDICT_v4_ROI_NII\PREDICT_01-093-24hrs-ich-Measurement.nii
# PREDICT_01-093-24hrs-ich-Measurement.raw
# PREDICT_01-100-24hrs-ich-Measurement.mhd
# PREDICT_01-100-24hrs-ich-Measurement
# F:\PREDICT\PREDICT_v4_ROI_NII\PREDICT_01-100-24hrs-ich-Measurement.nii
# PREDICT_01-100-24hrs-ich-Measurement.raw
# ...
