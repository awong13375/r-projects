# %%
import os, shutil
import ntpath
import sys
import subprocess
from shutil import copyfile
import SimpleITK as sitk
import time

path = r"C:\Users\alexw\Desktop\PREDICT"

for root, dirs, files in os.walk(path, topdown=False):

    break

# %%
dcmpath = r"D:\Alex Files\SPOTLIGHT\SPOTLIGHT"
mhdpath = r"D:\Alex Files\SPOTLIGHT\SPOTLIGHT_MHD_MAC"
dcmoutputpath = r"D:\Alex Files\SPOTLIGHT\SPOTLIGHT_DCM_NII"
mhdoutputpath = r"D:\Alex Files\SPOTLIGHT\SPOTLIGHT_ROI_NII"

# %%
reader = sitk.ImageSeriesReader()
reader2 = sitk.ImageFileReader()

i=0;
for r, d, f in os.walk(dcmpath):
    for 
for r, d, f in os.walk(dcmpath):
    for dir1 in d:
        direct1=r+"\\"+dir1
        #print(direct1)
        direct1b = direct1.replace('\\','\\\\')
        onlyfiles = next(os.walk(direct1b))[2] #dir is your directory path as string
        totalfiles = len(onlyfiles)
        if totalfiles > 5:
            thepath = ntpath.basename(direct1b)
            #print(thepath)
            dirfiles = os.listdir(direct1b)
            #print(dirfiles)
            print(direct1b)
            dicom_names = reader.GetGDCMSeriesFileNames(direct1b)
            reader.SetFileNames(dicom_names)
            image = reader.Execute()
            size = image.GetSize()
            #print(size)
            xarr = [];
            #get slice details
            for x in dirfiles:
                #print((direct1b+"\\\\"+x))
                reader2.SetFileName(direct1b+"\\\\"+x)
                reader2.LoadPrivateTagsOn();
                reader2.ReadImageInformation();
                xarr.append([{"slicesnum":reader2.GetMetaData("0020|0013"),"slicethick":reader2.GetMetaData("0018|0050")}])
            #print(xarr)
            #get name
            while True:
                direct1b = os.path.dirname(direct1b)
                #print(direct1b)
                pardir = ntpath.basename(direct1b)
                thepath = pardir + "-" + thepath
                if pardir == "SPOTLIGHT":
                    print(thepath)
                    break
            
            sitk.WriteImage(image, dcmoutputpath+"\\\\"+thepath+".nii")
            i = i+1
            
print(i);
# Out:
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\1-Baseline\\series_2_HEAD_STND
# SPOTLIGHT-002-0001-1-Baseline-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\1-Baseline\\series_3_HEAD_BONE
# SPOTLIGHT-002-0001-1-Baseline-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\3-24-hour Follow-up\\series_2_HEAD_STND
# SPOTLIGHT-002-0001-3-24-hour Follow-up-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\3-24-hour Follow-up\\series_300_HEAD_STND
# SPOTLIGHT-002-0001-3-24-hour Follow-up-series_300_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\3-24-hour Follow-up\\series_301_HEAD_BONE
# SPOTLIGHT-002-0001-3-24-hour Follow-up-series_301_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0001\\3-24-hour Follow-up\\series_4_HEAD_BONE
# SPOTLIGHT-002-0001-3-24-hour Follow-up-series_4_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\1-Baseline\\series_2_HEAD_STND
# SPOTLIGHT-002-0002-1-Baseline-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\1-Baseline\\series_3_HEAD_BONE
# SPOTLIGHT-002-0002-1-Baseline-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\2-post dose\\series_2_HEAD_STND
# SPOTLIGHT-002-0002-2-post dose-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\2-post dose\\series_3_HEAD_BONE
# SPOTLIGHT-002-0002-2-post dose-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\3-24-hour Follow-up\\series_2_HEAD_STND
# SPOTLIGHT-002-0002-3-24-hour Follow-up-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0002\\3-24-hour Follow-up\\series_3_HEAD_BONE
# SPOTLIGHT-002-0002-3-24-hour Follow-up-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\1-Baseline\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-1-Baseline-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\1-Baseline\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-1-Baseline-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\2-Post-dose\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-2-Post-dose-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\2-Post-dose\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-2-Post-dose-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\3-24-hour Follow-up\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-3-24-hour Follow-up-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\3-24-hour Follow-up\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-3-24-hour Follow-up-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_23815_20130518\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_23815_20130518-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_23815_20130518\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_23815_20130518-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_23825_20130518\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_23825_20130518-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_23825_20130518\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_23825_20130518-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_28119_20130522\\series_2_HEAD_STND
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_28119_20130522-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0003\\4-Greater than 24-hour Follow-up\\study_28119_20130522\\series_3_HEAD_BONE
# SPOTLIGHT-002-0003-4-Greater than 24-hour Follow-up-study_28119_20130522-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\1-Baseline_study_41448_20140623\\series_2_HEAD_STND
# SPOTLIGHT-002-0004-1-Baseline_study_41448_20140623-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\1-Baseline_study_41448_20140623\\series_3_HEAD_BONE
# SPOTLIGHT-002-0004-1-Baseline_study_41448_20140623-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\2-Post dose study_42938_20140623\\series_2_HEAD_STND
# SPOTLIGHT-002-0004-2-Post dose study_42938_20140623-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\2-Post dose study_42938_20140623\\series_3_HEAD_BONE
# SPOTLIGHT-002-0004-2-Post dose study_42938_20140623-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\3-study_41485_20140624\\series_2_HEAD_STND
# SPOTLIGHT-002-0004-3-study_41485_20140624-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\3-study_41485_20140624\\series_3_HEAD_BONE
# SPOTLIGHT-002-0004-3-study_41485_20140624-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\3-study_41485_20140624\\series_4_HEAD_STND
# SPOTLIGHT-002-0004-3-study_41485_20140624-series_4_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0004\\3-study_41485_20140624\\series_5_HEAD_BONE
# SPOTLIGHT-002-0004-3-study_41485_20140624-series_5_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\1.Baselinestudy_47991_20140926\\series_2_HEAD_STND
# SPOTLIGHT-002-0005-1.Baselinestudy_47991_20140926-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\1.Baselinestudy_47991_20140926\\series_3_HEAD_BONE
# SPOTLIGHT-002-0005-1.Baselinestudy_47991_20140926-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\2-postdosestudy_47993_20140926\\series_2_HEAD_STND
# SPOTLIGHT-002-0005-2-postdosestudy_47993_20140926-series_2_HEAD_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\2-postdosestudy_47993_20140926\\series_3_HEAD_BONE
# SPOTLIGHT-002-0005-2-postdosestudy_47993_20140926-series_3_HEAD_BONE
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\2-postdosestudy_47993_20140926\\series_4_THINS_STND
# SPOTLIGHT-002-0005-2-postdosestudy_47993_20140926-series_4_THINS_STND
# D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\2-postdosestudy_47993_20140926\\series_601_COR_HEAD_5MM
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-fc2672c0aa51> in <module>
#      27                 reader2.SetFileName(direct1b+"\\\\"+x)
#      28                 reader2.LoadPrivateTagsOn();
# ---> 29                 reader2.ReadImageInformation();
#      30                 xarr.append([{"slicesnum":reader2.GetMetaData("0020|0013"),"slicethick":reader2.GetMetaData("0018|0050")}])
#      31             #print(xarr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\SimpleITK\SimpleITK.py in ReadImageInformation(self)
#    8671
#    8672         """
# -> 8673         return _SimpleITK.ImageFileReader_ReadImageInformation(self)
#    8674
#    8675
#
# RuntimeError: Exception thrown in SimpleITK ImageFileReader_ReadImageInformation: C:\d\VS14-Win64-pkg\SimpleITK\Code\IO\src\sitkImageReaderBase.cxx:107:
# sitk::ERROR: Unable to determine ImageIO reader for "D:\\Alex Files\\SPOTLIGHT\\SPOTLIGHT\\002-0005\\2-postdosestudy_47993_20140926\\series_601_COR_HEAD_5MM\\91"
